# %%
import gymnasium as gym

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np

from IPython.display import clear_output

env = gym.make("MountainCar-v0", render_mode='rgb_array')
env.action_space.seed(42)
# Out:
# [42]

# %% [markdown]
# ## Test Environment

# %%
observation, info = env.reset(seed=42)

for _ in range(100):
    observation, reward, done, info, _ = env.step(env.action_space.sample())

    if done:
        break

    clear_output(wait=True)
    plt.imshow(env.render())
    plt.show()

env.close()

# %% [markdown]
# ## Q-learning

# %% [markdown]
# #### Create config

# %%
config = {'lr': 0.1,
          'gamma': 1,
          'eps1': 1,
          'eps2': 0.001,
          'decays': 10000}
decay = np.exp(np.log(config['eps2'] / config['eps1']) / config['decays'])

# %% [markdown]
# #### Discretie the states

# %%
n_bins = 101
bins = [np.linspace(-1.2, 0.6, n_bins),
        np.linspace(-0.07, 0.07, n_bins)
       ]
def digitize_state(state):
    stateIndex = []
    for i in range(len(bins)):
        stateIndex.append(np.digitize(state[i], bins[i]) - 1)
    return tuple(stateIndex)

# %% [markdown]
# #### Policy function

# %%
def policy(state):
    if np.random.random() < epsilon:
        return env.action_space.sample()
    return np.argmax(Q[state])

# %% [markdown]
# #### One episode

# %%
def run_episode():
    tot_rew = 0
    state, info = env.reset()
    dis_state = digitize_state(state)
    while True:
        action = policy(dis_state)
        observation, reward, terminated, truncated, info = env.step(action)
        next_dis_state = digitize_state(observation)

        TD = reward + config['gamma'] * np.max(Q[next_dis_state]) - Q[dis_state + (action,)]
        Q[dis_state + (action,)] += config['lr'] * TD

        tot_rew += reward

        if terminated or truncated:
            return tot_rew

        dis_state = next_dis_state

# %%
n_actions = env.action_space.n
Q = np.zeros(tuple([n_bins] * len(bins)) + (n_actions,))
epsilon = config['eps1']
episodes = 100000
log = {'episodes': [], 'rewards': []}
for episode in range(1, episodes+1):
    r = run_episode()
    log['rewards'].append(r)
    log['episodes'].append(episode)

    epsilon *= decay
    if epsilon < config['eps2']:
        epsilon = 0.
        
    if episode % 100 == 0:
        clear_output(wait=True)
        plt.plot(log['episodes'], log['rewards'])
        plt.xlabel('Episode')
        plt.ylabel('Reward')
        plt.show()
        print(Q.sum())
        print(epsilon)
# Out:
# -3339.4743966233223
# 0.8709635899560828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 7
#       5 log = {'episodes': [], 'rewards': []}
#       6 for episode in range(1, episodes+1):
# ----> 7     r = run_episode()
#       8     log['rewards'].append(r)
#       9     log['episodes'].append(episode)
#
# Cell In[6], line 7, in run_episode()
#       5 while True:
#       6     action = policy(dis_state)
# ----> 7     observation, reward, terminated, truncated, info = env.step(action)
#       8     next_dis_state = digitize_state(observation)
#      10     TD = reward + config['gamma'] * np.max(Q[next_dis_state]) - Q[dis_state + (action,)]
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~/anaconda3/envs/pytorch/lib/python3.10/site-packages/gymnasium/envs/classic_control/mountain_car.py:147, in MountainCarEnv.step(self, action)
#     144 reward = -1.0
#     146 self.state = (position, velocity)
# --> 147 if self.render_mode == "human":
#     148     self.render()
#     149 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# KeyboardInterrupt:
